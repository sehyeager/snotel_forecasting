# %% [markdown]
# # Precipitation in the Columbia River Basin on Feb 10th: 1990's Edition

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading in the data

# %%
df = pd.read_csv('output/merged.csv')

# %%
# Checking out the first five rows

df.head()
# Out:
#          Lat        Long    YYYYMMDD                 Basin_name Station_id  \
# 0  48.566667 -115.450000  19900210.0  KOOTENAI RIVER IN MONTANA        311
# 1  48.300000 -116.066667  19900210.0  KOOTENAI RIVER IN MONTANA        323
# 2  48.983333 -115.816667  19900210.0  KOOTENAI RIVER IN MONTANA        918
# 3  48.916667 -114.766667  19900210.0  KOOTENAI RIVER IN MONTANA        500
# 4  48.300000 -114.833333  19900210.0  KOOTENAI RIVER IN MONTANA        510
#
#   Acton_id       Station_name Elevation  Wteq_amt  Wteq_med  Wteq_amt_pct_med  \
# 0   15A08S  Banfield Mountain      5600      17.2      12.2             141.0
# 1   16A08S      Bear Mountain      5400      50.8      38.6             132.0
# 2   15A05S       Garver Creek      4250       8.1       6.9             117.0
# 3   14A11S        Grave Creek      4300      11.9      11.4             104.0
# 4   14A14S         Hand Creek      5035       9.8       7.8             126.0
#
#    Wteq_amt_pct_med_flag  Prec_wytd_amt  Prec_wytd_avg  Prec_wytd_pctavg  \
# 0                    NaN           23.8           17.8             134.0
# 1                    NaN           69.3           49.5             140.0
# 2                    NaN         -999.0           12.9               NaN
# 3                    NaN           32.8           22.8             144.0
# 4                    NaN           18.6           11.7             159.0
#
#    Prec_wytd_pct_avg_flag
# 0                     NaN  NaN
# 1                     NaN  NaN
# 2                  -997.0  NaN
# 3                     NaN  NaN
# 4                     NaN  NaN

# %%
# Checking rows and columns

df.shape
# Out:
# (3030, 17)

# %% [markdown]
# ### Cleaning the data

# %%
# Checking for null values

df.isnull().sum()
# Out:
# Lat                        240
# Long                       240
# YYYYMMDD                   240
# Basin_name                 240
# Station_id                   0
# Acton_id                   240
# Station_name               240
# Elevation                    0
# Wteq_amt                   240
# Wteq_med                   240
# Wteq_amt_pct_med           224
# Wteq_amt_pct_med_flag     2806
# Prec_wytd_amt              240
# Prec_wytd_avg              240
# Prec_wytd_pctavg           139
# Prec_wytd_pct_avg_flag    2891
#                           2800
# dtype: int64

# %%
# Checking the untitled column
df[' ']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 3025    NaN
# 3026    NaN
# 3027    NaN
# 3028    NaN
# 3029    NaN
# Name:  , Length: 3030, dtype: object

# %%
# Checking where the values are not null
df[df[' '].isnull() == False][' ']
# Out:
# 8
# 26
# 42
# 51
# 60
#        ..
# 2964
# 2978
# 2985
# 3007
# 3018
# Name:  , Length: 230, dtype: object

# %%
# Dropping the untitled column
df.drop(columns=' ', inplace=True)

# %%
# Checking what is going on with the missing values in Lat

df[df['Lat'].isnull() == True]
# Out:
#       Lat  Long  YYYYMMDD Basin_name  \
# 8     NaN   NaN       NaN        NaN
# 26    NaN   NaN       NaN        NaN
# 42    NaN   NaN       NaN        NaN
# 51    NaN   NaN       NaN        NaN
# 60    NaN   NaN       NaN        NaN
# ...   ...   ...       ...        ...
# 2978  NaN   NaN       NaN        NaN
# 2985  NaN   NaN       NaN        NaN
# 3007  NaN   NaN       NaN        NaN
# 3018  NaN   NaN       NaN        NaN
# 3029  NaN   NaN       NaN        NaN
#
#                                              Station_id Acton_id Station_name  \
# 8                             KOOTENAI RIVER IN MONTANA      NaN          NaN
# 26                                 FLATHEAD RIVER BASIN      NaN          NaN
# 42                         UPPER CLARK FORK RIVER BASIN      NaN          NaN
# 51                                           BITTERROOT      NaN          NaN
# 60                         LOWER CLARK FORK RIVER BASIN      NaN          NaN
# ...                                                 ...      ...          ...
# 2978                       DESCHUTES, CROOKED, JOHN DAY      NaN          NaN
# 2985                         LOWER COLUMBIA, HOOD RIVER      NaN          NaN
# 3007                                         WILLAMETTE      NaN          NaN
# 3018                                     LEWIS, COWLITZ      NaN          NaN
# 3029  WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAK...      NaN          NaN
#
#             Elevation  Wteq_amt  Wteq_med  Wteq_amt_pct_med  \
# 8     Basin Index (%)       NaN       NaN             129.0
# 26    Basin Index (%)       NaN       NaN             132.0
# 42    Basin Index (%)       NaN       NaN             113.0
# 51    Basin Index (%)       NaN       NaN             118.0
# 60    Basin Index (%)       NaN       NaN             134.0
# ...               ...       ...       ...               ...
# 2978  Basin Index (%)       NaN       NaN             175.0
# 2985  Basin Index (%)       NaN       NaN             138.0
# 3007  Basin Index (%)       NaN       NaN             192.0
# 3018  Basin Index (%)       NaN       NaN             191.0
# 3029  Basin Index (%)       NaN       NaN             148.0
#
#       Wteq_amt_pct_med_flag  Prec_wytd_amt  Prec_wytd_avg  Prec_wytd_pctavg  \
# 8                       NaN            NaN            NaN             140.0
# 26                      NaN            NaN            NaN             142.0
# 42                      NaN            NaN            NaN             120.0
# 51                      NaN            NaN            NaN             115.0
# 60                      NaN            NaN            NaN             138.0
# ...                     ...            ...            ...               ...
# 2978                    NaN            NaN            NaN             132.0
# 2985                    NaN            NaN            NaN             133.0
# 3007                    NaN            NaN            NaN             138.0
# 3018                    NaN            NaN            NaN             148.0
# 3029                    NaN            NaN            NaN             135.0
#
#       Prec_wytd_pct_avg_flag
# 8                        NaN
# 26                       NaN
# 42                       NaN
# 51                       NaN
# 60                       NaN
# ...                      ...
# 2978                     NaN
# 2985                     NaN
# 3007                     NaN
# 3018                     NaN
# 3029                     NaN
#
# [240 rows x 16 columns]

# %%
# It looks like a lot of those 240 null values are all missing from the same rows, it also looks like the only
# useful information in those rows is the current snow water equivalent as percent of median and water year to 
# date precipitation as percent of average.

# %%
# Checking the first station that showed up in the missing rows to see if any of the reports are useful

df[df['Station_id'] == 'KOOTENAI RIVER IN MONTANA']
# Out:
#       Lat  Long  YYYYMMDD Basin_name                 Station_id Acton_id  \
# 8     NaN   NaN       NaN        NaN  KOOTENAI RIVER IN MONTANA      NaN
# 311   NaN   NaN       NaN        NaN  KOOTENAI RIVER IN MONTANA      NaN
# 614   NaN   NaN       NaN        NaN  KOOTENAI RIVER IN MONTANA      NaN
# 917   NaN   NaN       NaN        NaN  KOOTENAI RIVER IN MONTANA      NaN
# 1220  NaN   NaN       NaN        NaN  KOOTENAI RIVER IN MONTANA      NaN
# 1523  NaN   NaN       NaN        NaN  KOOTENAI RIVER IN MONTANA      NaN
# 1826  NaN   NaN       NaN        NaN  KOOTENAI RIVER IN MONTANA      NaN
# 2129  NaN   NaN       NaN        NaN  KOOTENAI RIVER IN MONTANA      NaN
# 2432  NaN   NaN       NaN        NaN  KOOTENAI RIVER IN MONTANA      NaN
# 2735  NaN   NaN       NaN        NaN  KOOTENAI RIVER IN MONTANA      NaN
#
#      Station_name        Elevation  Wteq_amt  Wteq_med  Wteq_amt_pct_med  \
# 8             NaN  Basin Index (%)       NaN       NaN             129.0
# 311           NaN  Basin Index (%)       NaN       NaN             142.0
# 614           NaN  Basin Index (%)       NaN       NaN              95.0
# 917           NaN  Basin Index (%)       NaN       NaN              86.0
# 1220          NaN  Basin Index (%)       NaN       NaN              72.0
# 1523          NaN  Basin Index (%)       NaN       NaN             114.0
# 1826          NaN  Basin Index (%)       NaN       NaN             127.0
# 2129          NaN  Basin Index (%)       NaN       NaN             162.0
# 2432          NaN  Basin Index (%)       NaN       NaN              91.0
# 2735          NaN  Basin Index (%)       NaN       NaN             163.0
#
#       Wteq_amt_pct_med_flag  Prec_wytd_amt  Prec_wytd_avg  Prec_wytd_pctavg  \
# 8                       NaN            NaN            NaN             140.0
# 311                     NaN            NaN            NaN             147.0
# 614                     NaN            NaN            NaN              79.0
# 917                     NaN            NaN            NaN              71.0
# 1220                    NaN            NaN            NaN              60.0
# 1523                    NaN            NaN            NaN             109.0
# 1826                    NaN            NaN            NaN             161.0
# 2129                    NaN            NaN            NaN             132.0
# 2432                    NaN            NaN            NaN              83.0
# 2735                    NaN            NaN            NaN             131.0
#
#       Prec_wytd_pct_avg_flag
# 8                        NaN
# 311                      NaN
# 614                      NaN
# 917                      NaN
# 1220                     NaN
# 1523                     NaN
# 1826                     NaN
# 2129                     NaN
# 2432                     NaN
# 2735                     NaN

# %%
# It looks like every report from this station is missing the same values.

# %%
# Double checking data types

df.dtypes
# Out:
# Lat                       float64
# Long                      float64
# YYYYMMDD                  float64
# Basin_name                 object
# Station_id                 object
# Acton_id                   object
# Station_name               object
# Elevation                  object
# Wteq_amt                  float64
# Wteq_med                  float64
# Wteq_amt_pct_med          float64
# Wteq_amt_pct_med_flag     float64
# Prec_wytd_amt             float64
# Prec_wytd_avg             float64
# Prec_wytd_pctavg          float64
# Prec_wytd_pct_avg_flag    float64
# dtype: object

# %%
# The 'YYYMMDD' column needs to be set to a datetime

df['YYYYMMDD'] = pd.to_datetime(df['YYYYMMDD'], format='%Y%m%d')

# %%
# Making sure the type changed to datetime object

df.dtypes
# Out:
# Lat                              float64
# Long                             float64
# YYYYMMDD                  datetime64[ns]
# Basin_name                        object
# Station_id                        object
# Acton_id                          object
# Station_name                      object
# Elevation                         object
# Wteq_amt                         float64
# Wteq_med                         float64
# Wteq_amt_pct_med                 float64
# Wteq_amt_pct_med_flag            float64
# Prec_wytd_amt                    float64
# Prec_wytd_avg                    float64
# Prec_wytd_pctavg                 float64
# Prec_wytd_pct_avg_flag           float64
# dtype: object

# %%
# Setting the index to be the datetime

df.set_index('YYYYMMDD', inplace = True)

# %%
# Sorting the data by date

df.sort_index(inplace = True)

# %%
# Trying to get an initial look at some distribution

plt.hist(df['Wteq_amt']);

# %%
# Checking the values in the dataset

df.describe()
# Out:
#                Lat         Long     Wteq_amt     Wteq_med  Wteq_amt_pct_med  \
# count  2790.000000  2790.000000  2790.000000  2790.000000       2806.000000
# mean     45.436141  -116.455376   -27.556559   -31.321505        110.602281
# std       1.865060     3.543578   209.865561   213.899963         45.238525
# min      41.233333  -123.366667  -999.000000  -998.000000          0.000000
# 25%      43.950000  -119.933333     8.300000     9.200000         81.000000
# 50%      45.183333  -115.700000    14.000000    13.400000        103.000000
# 75%      47.000000  -113.950000    22.875000    20.700000        137.000000
# max      48.983333  -110.050000    71.900000    47.600000        594.000000
#
#        Wteq_amt_pct_med_flag  Prec_wytd_amt  Prec_wytd_avg  Prec_wytd_pctavg  \
# count                  224.0    2790.000000    2790.000000       2891.000000
# mean                  -997.0     -20.403728       6.551613        107.709097
# std                      0.0     216.351167     136.567327         34.950773
# min                   -997.0    -999.000000    -998.000000         32.000000
# 25%                   -997.0      12.300000      13.800000         81.000000
# 50%                   -997.0      20.300000      21.000000        103.000000
# 75%                   -997.0      33.600000      31.000000        131.000000
# max                   -997.0     160.500000      99.400000        234.000000
#
#        Prec_wytd_pct_avg_flag
# count                   139.0
# mean                   -997.0
# std                       0.0
# min                    -997.0
# 25%                    -997.0
# 50%                    -997.0
# 75%                    -997.0
# max                    -997.0

# %%
# Some data is entered as negative numbers when they should be null values.
# -997 : Data may not provide valid measure of contitions
# -998 : No normal available
# -999 : Missing data

# %%
df['Wteq_amt'].value_counts()
# Out:
# -999.0    124
#  8.1       27
#  0.0       24
#  9.3       23
#  7.0       21
#          ...
#  58.4       1
#  2.4        1
#  71.9       1
#  45.3       1
#  1.6        1
# Name: Wteq_amt, Length: 473, dtype: int64

# %%
# Replacing the negative values with null values

df.replace(-997.0, np.nan, inplace = True)
df.replace(-998.0, np.nan, inplace = True)
df.replace(-999.0, np.nan, inplace = True)

# %%
# Double checking the earlier distribution
plt.hist(df['Wteq_amt']);

# %%
# Initial check of another distribution

plt.hist(df['Wteq_amt_pct_med']);

# %%
# Seeing how many null values exist after converting the numbers to null


df.isnull().sum()
# Out:
# Lat                        240
# Long                       240
# Basin_name                 240
# Station_id                   0
# Acton_id                   240
# Station_name               240
# Elevation                    0
# Wteq_amt                   364
# Wteq_med                   370
# Wteq_amt_pct_med           224
# Wteq_amt_pct_med_flag     3030
# Prec_wytd_amt              369
# Prec_wytd_avg              290
# Prec_wytd_pctavg           139
# Prec_wytd_pct_avg_flag    3030
# dtype: int64

# %%
# Double checking values in the data

df.describe()
# Out:
#                Lat         Long     Wteq_amt     Wteq_med  Wteq_amt_pct_med  \
# count  2790.000000  2790.000000  2666.000000  2660.000000       2806.000000
# mean     45.436141  -116.455376    17.626857    15.922180        110.602281
# std       1.865060     3.543578    11.872219     8.405817         45.238525
# min      41.233333  -123.366667     0.000000     0.000000          0.000000
# 25%      43.950000  -119.933333     9.125000     9.800000         81.000000
# 50%      45.183333  -115.700000    14.650000    14.000000        103.000000
# 75%      47.000000  -113.950000    23.500000    20.900000        137.000000
# max      48.983333  -110.050000    71.900000    47.600000        594.000000
#
#        Wteq_amt_pct_med_flag  Prec_wytd_amt  Prec_wytd_avg  Prec_wytd_pctavg  \
# count                    0.0    2661.000000    2740.000000       2891.000000
# mean                     NaN      27.036678      24.882847        107.709097
# std                      NaN      19.594281      15.282298         34.950773
# min                      NaN       2.700000       6.000000         32.000000
# 25%                      NaN      13.400000      14.100000         81.000000
# 50%                      NaN      21.300000      21.100000        103.000000
# 75%                      NaN      34.500000      31.700000        131.000000
# max                      NaN     160.500000      99.400000        234.000000
#
#        Prec_wytd_pct_avg_flag
# count                     0.0
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %%
# Checking for any good values in the flag columns

df['Wteq_amt_pct_med_flag'].value_counts()
# Out:
# Series([], Name: Wteq_amt_pct_med_flag, dtype: int64)

# %%
df['Prec_wytd_pct_avg_flag'].value_counts()
# Out:
# Series([], Name: Prec_wytd_pct_avg_flag, dtype: int64)

# %%
# Dropping columns full of null values (flag columns) as even the values not already nulled represent an invalid
# measure of contitions according to the data dictionary.

df.drop(columns = ['Wteq_amt_pct_med_flag', 'Prec_wytd_pct_avg_flag'], inplace = True)

# %%
df.isnull().sum()
# Out:
# Lat                 240
# Long                240
# Basin_name          240
# Station_id            0
# Acton_id            240
# Station_name        240
# Elevation             0
# Wteq_amt            364
# Wteq_med            370
# Wteq_amt_pct_med    224
# Prec_wytd_amt       369
# Prec_wytd_avg       290
# Prec_wytd_pctavg    139
# dtype: int64

# %%
# Checking for stations with no values for current snow water

df[df['Wteq_amt'].isnull()].groupby('Station_id').mean()
# Out:
#                                                           Lat        Long  \
# Station_id
# 1068                                                47.166667 -121.416667
# 1084                                                45.250000 -123.283333
# 1144                                                47.983333 -114.350000
# 1165                                                48.200000 -114.516667
# 346                                                 47.683333 -114.000000
# 382                                                 43.266667 -115.350000
# 535                                                 47.533333 -115.783333
# 549                                                 41.516667 -116.016667
# 599                                                 46.350000 -121.083333
# 623                                                 47.150000 -116.266667
# 644                                                 48.366667 -119.083333
# 752                                                 46.950000 -116.333333
# 783                                                 47.183333 -114.333333
# 871                                                 42.016667 -115.000000
# 895                                                 43.766667 -114.416667
# 897                                                 47.283333 -121.466667
# 898                                                 47.350000 -121.566667
# 899                                                 47.333333 -121.466667
# 901                                                 47.000000 -113.933333
# 903                                                 46.850000 -112.500000
# 932                                                 48.133333 -115.616667
# BIG AND LITTLE LOST BASINS                                NaN         NaN
# BIG AND LITTLE WOOD BASINS                                NaN         NaN
# BITTERROOT                                                NaN         NaN
# CHELAN, ENTIAT, WENATCHEE                                 NaN         NaN
# CLEARWATER AND SALMON                                     NaN         NaN
# COLUMBIA ABOVE METHOW                                     NaN         NaN
# DESCHUTES, CROOKED, JOHN DAY                              NaN         NaN
# FLATHEAD RIVER BASIN                                      NaN         NaN
# GRAND RONDE, POWDER, BURNT, IMNAHA                        NaN         NaN
# HENRYS FORK, TETON, WILLOW, BLACKFOOT, PORTNEUF           NaN         NaN
# IDAHO PANHANDLE REGION                                    NaN         NaN
# KOOTENAI RIVER IN MONTANA                                 NaN         NaN
# LEWIS, COWLITZ                                            NaN         NaN
# LOWER CLARK FORK RIVER BASIN                              NaN         NaN
# LOWER COLUMBIA, HOOD RIVER                                NaN         NaN
# OWYHEE MALHEUR                                            NaN         NaN
# RAFT, GOOSE, SALMON FALLS, BRUNEAU                        NaN         NaN
# SNAKE ABOVE PALISADES                                     NaN         NaN
# UMATILLA, WALLA WALLA, WILLOW                             NaN         NaN
# UPPER CLARK FORK RIVER BASIN                              NaN         NaN
# WEISER, PAYETTE, BOISE                                    NaN         NaN
# WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAKE...        NaN         NaN
# WILLAMETTE                                                NaN         NaN
# YAKIMA, AHTANUM                                           NaN         NaN
#
#                                                     Wteq_amt  Wteq_med  \
# Station_id
# 1068                                                     NaN       NaN
# 1084                                                     NaN       NaN
# 1144                                                     NaN       NaN
# 1165                                                     NaN       NaN
# 346                                                      NaN       6.8
# 382                                                      NaN       9.7
# 535                                                      NaN       8.9
# 549                                                      NaN       NaN
# 599                                                      NaN      14.7
# 623                                                      NaN      17.6
# 644                                                      NaN      10.6
# 752                                                      NaN       8.3
# 783                                                      NaN      10.1
# 871                                                      NaN       9.9
# 895                                                      NaN       9.0
# 897                                                      NaN      17.9
# 898                                                      NaN      13.5
# 899                                                      NaN      21.4
# 901                                                      NaN      21.9
# 903                                                      NaN       9.4
# 932                                                      NaN      23.7
# BIG AND LITTLE LOST BASINS                               NaN       NaN
# BIG AND LITTLE WOOD BASINS                               NaN       NaN
# BITTERROOT                                               NaN       NaN
# CHELAN, ENTIAT, WENATCHEE                                NaN       NaN
# CLEARWATER AND SALMON                                    NaN       NaN
# COLUMBIA ABOVE METHOW                                    NaN       NaN
# DESCHUTES, CROOKED, JOHN DAY                             NaN       NaN
# FLATHEAD RIVER BASIN                                     NaN       NaN
# GRAND RONDE, POWDER, BURNT, IMNAHA                       NaN       NaN
# HENRYS FORK, TETON, WILLOW, BLACKFOOT, PORTNEUF          NaN       NaN
# IDAHO PANHANDLE REGION                                   NaN       NaN
# KOOTENAI RIVER IN MONTANA                                NaN       NaN
# LEWIS, COWLITZ                                           NaN       NaN
# LOWER CLARK FORK RIVER BASIN                             NaN       NaN
# LOWER COLUMBIA, HOOD RIVER                               NaN       NaN
# OWYHEE MALHEUR                                           NaN       NaN
# RAFT, GOOSE, SALMON FALLS, BRUNEAU                       NaN       NaN
# SNAKE ABOVE PALISADES                                    NaN       NaN
# UMATILLA, WALLA WALLA, WILLOW                            NaN       NaN
# UPPER CLARK FORK RIVER BASIN                             NaN       NaN
# WEISER, PAYETTE, BOISE                                   NaN       NaN
# WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAKE...       NaN       NaN
# WILLAMETTE                                               NaN       NaN
# YAKIMA, AHTANUM                                          NaN       NaN
#
#                                                     Wteq_amt_pct_med  \
# Station_id
# 1068                                                             NaN
# 1084                                                             NaN
# 1144                                                             NaN
# 1165                                                             NaN
# 346                                                              NaN
# 382                                                              NaN
# 535                                                              NaN
# 549                                                              NaN
# 599                                                              NaN
# 623                                                              NaN
# 644                                                              NaN
# 752                                                              NaN
# 783                                                              NaN
# 871                                                              NaN
# 895                                                              NaN
# 897                                                              NaN
# 898                                                              NaN
# 899                                                              NaN
# 901                                                              NaN
# 903                                                              NaN
# 932                                                              NaN
# BIG AND LITTLE LOST BASINS                                     116.7
# BIG AND LITTLE WOOD BASINS                                     110.9
# BITTERROOT                                                     116.6
# CHELAN, ENTIAT, WENATCHEE                                      113.3
# CLEARWATER AND SALMON                                          113.5
# COLUMBIA ABOVE METHOW                                          123.6
# DESCHUTES, CROOKED, JOHN DAY                                   105.7
# FLATHEAD RIVER BASIN                                           120.0
# GRAND RONDE, POWDER, BURNT, IMNAHA                             103.3
# HENRYS FORK, TETON, WILLOW, BLACKFOOT, PORTNEUF                115.6
# IDAHO PANHANDLE REGION                                         112.3
# KOOTENAI RIVER IN MONTANA                                      118.1
# LEWIS, COWLITZ                                                 105.7
# LOWER CLARK FORK RIVER BASIN                                   119.4
# LOWER COLUMBIA, HOOD RIVER                                      97.8
# OWYHEE MALHEUR                                                 103.5
# RAFT, GOOSE, SALMON FALLS, BRUNEAU                             103.9
# SNAKE ABOVE PALISADES                                          114.7
# UMATILLA, WALLA WALLA, WILLOW                                   99.0
# UPPER CLARK FORK RIVER BASIN                                   114.1
# WEISER, PAYETTE, BOISE                                         109.2
# WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAKE...             110.0
# WILLAMETTE                                                     104.0
# YAKIMA, AHTANUM                                                113.4
#
#                                                     Prec_wytd_amt  \
# Station_id
# 1068                                                          NaN
# 1084                                                          NaN
# 1144                                                          NaN
# 1165                                                          NaN
# 346                                                           NaN
# 382                                                           NaN
# 535                                                         44.90
# 549                                                         15.95
# 599                                                           NaN
# 623                                                           NaN
# 644                                                           NaN
# 752                                                         25.20
# 783                                                           NaN
# 871                                                           NaN
# 895                                                           NaN
# 897                                                           NaN
# 898                                                           NaN
# 899                                                           NaN
# 901                                                           NaN
# 903                                                           NaN
# 932                                                           NaN
# BIG AND LITTLE LOST BASINS                                    NaN
# BIG AND LITTLE WOOD BASINS                                    NaN
# BITTERROOT                                                    NaN
# CHELAN, ENTIAT, WENATCHEE                                     NaN
# CLEARWATER AND SALMON                                         NaN
# COLUMBIA ABOVE METHOW                                         NaN
# DESCHUTES, CROOKED, JOHN DAY                                  NaN
# FLATHEAD RIVER BASIN                                          NaN
# GRAND RONDE, POWDER, BURNT, IMNAHA                            NaN
# HENRYS FORK, TETON, WILLOW, BLACKFOOT, PORTNEUF               NaN
# IDAHO PANHANDLE REGION                                        NaN
# KOOTENAI RIVER IN MONTANA                                     NaN
# LEWIS, COWLITZ                                                NaN
# LOWER CLARK FORK RIVER BASIN                                  NaN
# LOWER COLUMBIA, HOOD RIVER                                    NaN
# OWYHEE MALHEUR                                                NaN
# RAFT, GOOSE, SALMON FALLS, BRUNEAU                            NaN
# SNAKE ABOVE PALISADES                                         NaN
# UMATILLA, WALLA WALLA, WILLOW                                 NaN
# UPPER CLARK FORK RIVER BASIN                                  NaN
# WEISER, PAYETTE, BOISE                                        NaN
# WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAKE...            NaN
# WILLAMETTE                                                    NaN
# YAKIMA, AHTANUM                                               NaN
#
#                                                     Prec_wytd_avg  \
# Station_id
# 1068                                                          NaN
# 1084                                                          NaN
# 1144                                                          NaN
# 1165                                                          NaN
# 346                                                          11.5
# 382                                                          12.9
# 535                                                          26.6
# 549                                                          17.3
# 599                                                          20.6
# 623                                                          30.6
# 644                                                          13.1
# 752                                                          21.0
# 783                                                          14.7
# 871                                                          11.6
# 895                                                          11.7
# 897                                                          56.1
# 898                                                          58.4
# 899                                                          61.1
# 901                                                          22.8
# 903                                                          11.5
# 932                                                          39.8
# BIG AND LITTLE LOST BASINS                                    NaN
# BIG AND LITTLE WOOD BASINS                                    NaN
# BITTERROOT                                                    NaN
# CHELAN, ENTIAT, WENATCHEE                                     NaN
# CLEARWATER AND SALMON                                         NaN
# COLUMBIA ABOVE METHOW                                         NaN
# DESCHUTES, CROOKED, JOHN DAY                                  NaN
# FLATHEAD RIVER BASIN                                          NaN
# GRAND RONDE, POWDER, BURNT, IMNAHA                            NaN
# HENRYS FORK, TETON, WILLOW, BLACKFOOT, PORTNEUF               NaN
# IDAHO PANHANDLE REGION                                        NaN
# KOOTENAI RIVER IN MONTANA                                     NaN
# LEWIS, COWLITZ                                                NaN
# LOWER CLARK FORK RIVER BASIN                                  NaN
# LOWER COLUMBIA, HOOD RIVER                                    NaN
# OWYHEE MALHEUR                                                NaN
# RAFT, GOOSE, SALMON FALLS, BRUNEAU                            NaN
# SNAKE ABOVE PALISADES                                         NaN
# UMATILLA, WALLA WALLA, WILLOW                                 NaN
# UPPER CLARK FORK RIVER BASIN                                  NaN
# WEISER, PAYETTE, BOISE                                        NaN
# WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAKE...            NaN
# WILLAMETTE                                                    NaN
# YAKIMA, AHTANUM                                               NaN
#
#                                                     Prec_wytd_pctavg
# Station_id
# 1068                                                             NaN
# 1084                                                             NaN
# 1144                                                             NaN
# 1165                                                             NaN
# 346                                                              NaN
# 382                                                              NaN
# 535                                                            169.0
# 549                                                             92.2
# 599                                                              NaN
# 623                                                              NaN
# 644                                                              NaN
# 752                                                            120.0
# 783                                                              NaN
# 871                                                              NaN
# 895                                                              NaN
# 897                                                              NaN
# 898                                                              NaN
# 899                                                              NaN
# 901                                                              NaN
# 903                                                              NaN
# 932                                                              NaN
# BIG AND LITTLE LOST BASINS                                     108.5
# BIG AND LITTLE WOOD BASINS                                     106.4
# BITTERROOT                                                     111.2
# CHELAN, ENTIAT, WENATCHEE                                      110.2
# CLEARWATER AND SALMON                                          109.2
# COLUMBIA ABOVE METHOW                                          108.8
# DESCHUTES, CROOKED, JOHN DAY                                   105.2
# FLATHEAD RIVER BASIN                                           113.8
# GRAND RONDE, POWDER, BURNT, IMNAHA                             102.1
# HENRYS FORK, TETON, WILLOW, BLACKFOOT, PORTNEUF                107.0
# IDAHO PANHANDLE REGION                                         109.7
# KOOTENAI RIVER IN MONTANA                                      111.3
# LEWIS, COWLITZ                                                 110.2
# LOWER CLARK FORK RIVER BASIN                                   112.5
# LOWER COLUMBIA, HOOD RIVER                                     108.6
# OWYHEE MALHEUR                                                  98.3
# RAFT, GOOSE, SALMON FALLS, BRUNEAU                              97.3
# SNAKE ABOVE PALISADES                                          107.5
# UMATILLA, WALLA WALLA, WILLOW                                  102.5
# UPPER CLARK FORK RIVER BASIN                                   109.9
# WEISER, PAYETTE, BOISE                                         106.6
# WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAKE...             111.9
# WILLAMETTE                                                     108.2
# YAKIMA, AHTANUM                                                111.1

# %%
# Using SimpleImputer to impute values
# imp_med = SimpleImputer(missing_values = np.nan, strategy = 'median')

# List of columns to impute values for
# imp_list = ['wteq_amt', 'wteq_med', 'wteq_amt_pct_med', 'prec_wytd_amt', 'prec_wytd_avg', 'prec_wytd_pctavg']

#for i in range(10):
    #current_year = df[df.index.year == (1990 + i)]
    #for column in current_year.columns:
        #if column in imp_list:
            #imp_med.fit_transform(current_year[column])
            #df[df.index.year == (1990 + i)][column] = current_year[column]

# %%
# Changing the names of the columns to be easier to work with

lower_cols = [column.lower() for column in df.columns]

df.columns = lower_cols
df.head()
# Out:
#                   lat        long                          basin_name  \
# YYYYMMDD
# 1990-02-10  48.566667 -115.450000           KOOTENAI RIVER IN MONTANA
# 1990-02-10  45.000000 -117.166667  GRAND RONDE, POWDER, BURNT, IMNAHA
# 1990-02-10  45.083333 -117.550000  GRAND RONDE, POWDER, BURNT, IMNAHA
# 1990-02-10  45.066667 -118.150000  GRAND RONDE, POWDER, BURNT, IMNAHA
# 1990-02-10  44.300000 -115.233333               CLEARWATER AND SALMON
#
#            station_id acton_id       station_name elevation  wteq_amt  \
# YYYYMMDD
# 1990-02-10        311   15A08S  Banfield Mountain      5600      17.2
# 1990-02-10        736   17D08S  Schneider Meadows      5400      21.6
# 1990-02-10        812   17D07S       Taylor Green      5740       9.8
# 1990-02-10        873   18D21S         Wolf Creek      5630       8.4
# 1990-02-10        312   15E11S      Banner Summit      7040      15.1
#
#             wteq_med  wteq_amt_pct_med  prec_wytd_amt  prec_wytd_avg  \
# YYYYMMDD
# 1990-02-10      12.2             141.0           23.8           17.8
# 1990-02-10      22.0              98.0           21.3           26.7
# 1990-02-10      15.2              64.0           15.0           19.2
# 1990-02-10      12.6              67.0           10.2           14.5
# 1990-02-10      16.8              90.0           18.4           21.0
#
#             prec_wytd_pctavg
# YYYYMMDD
# 1990-02-10             134.0
# 1990-02-10              80.0
# 1990-02-10              78.0
# 1990-02-10              70.0
# 1990-02-10              88.0

# %%
df.shape
# Out:
# (3030, 13)

# %%
df[df.index.isnull() == True]
# Out:
#           lat  long basin_name  \
# YYYYMMDD
# NaT       NaN   NaN        NaN
# NaT       NaN   NaN        NaN
# NaT       NaN   NaN        NaN
# NaT       NaN   NaN        NaN
# NaT       NaN   NaN        NaN
# ...       ...   ...        ...
# NaT       NaN   NaN        NaN
# NaT       NaN   NaN        NaN
# NaT       NaN   NaN        NaN
# NaT       NaN   NaN        NaN
# NaT       NaN   NaN        NaN
#
#                                                  station_id acton_id  \
# YYYYMMDD
# NaT                               KOOTENAI RIVER IN MONTANA      NaN
# NaT                                    FLATHEAD RIVER BASIN      NaN
# NaT                            UPPER CLARK FORK RIVER BASIN      NaN
# NaT                                              BITTERROOT      NaN
# NaT                            LOWER CLARK FORK RIVER BASIN      NaN
# ...                                                     ...      ...
# NaT                            DESCHUTES, CROOKED, JOHN DAY      NaN
# NaT                              LOWER COLUMBIA, HOOD RIVER      NaN
# NaT                                              WILLAMETTE      NaN
# NaT                                          LEWIS, COWLITZ      NaN
# NaT       WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAK...      NaN
#
#          station_name        elevation  wteq_amt  wteq_med  wteq_amt_pct_med  \
# YYYYMMDD
# NaT               NaN  Basin Index (%)       NaN       NaN             129.0
# NaT               NaN  Basin Index (%)       NaN       NaN             132.0
# NaT               NaN  Basin Index (%)       NaN       NaN             113.0
# NaT               NaN  Basin Index (%)       NaN       NaN             118.0
# NaT               NaN  Basin Index (%)       NaN       NaN             134.0
# ...               ...              ...       ...       ...               ...
# NaT               NaN  Basin Index (%)       NaN       NaN             175.0
# NaT               NaN  Basin Index (%)       NaN       NaN             138.0
# NaT               NaN  Basin Index (%)       NaN       NaN             192.0
# NaT               NaN  Basin Index (%)       NaN       NaN             191.0
# NaT               NaN  Basin Index (%)       NaN       NaN             148.0
#
#           prec_wytd_amt  prec_wytd_avg  prec_wytd_pctavg
# YYYYMMDD
# NaT                 NaN            NaN             140.0
# NaT                 NaN            NaN             142.0
# NaT                 NaN            NaN             120.0
# NaT                 NaN            NaN             115.0
# NaT                 NaN            NaN             138.0
# ...                 ...            ...               ...
# NaT                 NaN            NaN             132.0
# NaT                 NaN            NaN             133.0
# NaT                 NaN            NaN             138.0
# NaT                 NaN            NaN             148.0
# NaT                 NaN            NaN             135.0
#
# [240 rows x 13 columns]

# %%
# Dropping values with no time to work with

df = df.loc[df.index.notnull()]

# %%
df.shape
# Out:
# (2790, 13)

# %%
#list of all my features with nulls after dropping those two flag columns and changing all the codes to nulls as well
features_to_fill = ['wteq_amt', 'wteq_med', 'wteq_amt_pct_med', 'prec_wytd_amt', 'prec_wytd_avg', 'prec_wytd_pctavg']

#groups by year, and then fills the nulls with the year's median value
def null_filler(feature):
    return df.groupby(by = df.index)[feature].transform(lambda x: x.fillna(x.median()))

#fills the nulls of every feature in my above list
for feature in features_to_fill:
    df[feature] = null_filler(feature)

# %%
df.isnull().sum()
# Out:
# lat                 0
# long                0
# basin_name          0
# station_id          0
# acton_id            0
# station_name        0
# elevation           0
# wteq_amt            0
# wteq_med            0
# wteq_amt_pct_med    0
# prec_wytd_amt       0
# prec_wytd_avg       0
# prec_wytd_pctavg    0
# dtype: int64

# %%
# Savin

df.to_csv('90s-data.csv')

# %%
df_2000s = pd.read_csv('basin_2000_2010.csv')
df_2010s = pd.read_csv('sams_clean_data.csv')

# %%
df.head()
# Out:
#                   lat        long                          basin_name  \
# YYYYMMDD
# 1990-02-10  48.566667 -115.450000           KOOTENAI RIVER IN MONTANA
# 1990-02-10  45.000000 -117.166667  GRAND RONDE, POWDER, BURNT, IMNAHA
# 1990-02-10  45.083333 -117.550000  GRAND RONDE, POWDER, BURNT, IMNAHA
# 1990-02-10  45.066667 -118.150000  GRAND RONDE, POWDER, BURNT, IMNAHA
# 1990-02-10  44.300000 -115.233333               CLEARWATER AND SALMON
#
#            station_id acton_id       station_name elevation  wteq_amt  \
# YYYYMMDD
# 1990-02-10        311   15A08S  Banfield Mountain      5600      17.2
# 1990-02-10        736   17D08S  Schneider Meadows      5400      21.6
# 1990-02-10        812   17D07S       Taylor Green      5740       9.8
# 1990-02-10        873   18D21S         Wolf Creek      5630       8.4
# 1990-02-10        312   15E11S      Banner Summit      7040      15.1
#
#             wteq_med  wteq_amt_pct_med  prec_wytd_amt  prec_wytd_avg  \
# YYYYMMDD
# 1990-02-10      12.2             141.0           23.8           17.8
# 1990-02-10      22.0              98.0           21.3           26.7
# 1990-02-10      15.2              64.0           15.0           19.2
# 1990-02-10      12.6              67.0           10.2           14.5
# 1990-02-10      16.8              90.0           18.4           21.0
#
#             prec_wytd_pctavg
# YYYYMMDD
# 1990-02-10             134.0
# 1990-02-10              80.0
# 1990-02-10              78.0
# 1990-02-10              70.0
# 1990-02-10              88.0

# %%
df_2000s.head()
# Out:
#          lat        long    yyyymmdd                 basin_name  station_id  \
# 0  48.566667 -115.450000  2009-02-10  KOOTENAI RIVER IN MONTANA         311
# 1  48.300000 -116.066667  2009-02-10  KOOTENAI RIVER IN MONTANA         323
# 2  48.983333 -115.816667  2009-02-10  KOOTENAI RIVER IN MONTANA         918
# 3  48.916667 -114.766667  2009-02-10  KOOTENAI RIVER IN MONTANA         500
# 4  48.300000 -114.833333  2009-02-10  KOOTENAI RIVER IN MONTANA         510
#
#   acton_id       station_name  elevation  wteq_amt  wteq_med  \
# 0   15A08S  Banfield Mountain       5600      11.4      12.2
# 1   16A08S      Bear Mountain       5400      27.6      38.6
# 2   15A05S       Garver Creek       4250       6.3       6.9
# 3   14A11S        Grave Creek       4300       9.3      11.4
# 4   14A14S         Hand Creek       5035      10.7       7.8
#
#    wteq_amt_pct_med  prec_wytd_amt  prec_wytd_avg  prec_wytd_pctavg
# 0              93.0           13.6           17.8              76.0
# 1              72.0           34.5           49.5              70.0
# 2              91.0            9.6           12.9              74.0
# 3              82.0           18.8           22.8              82.0
# 4             137.0           13.6           11.7             116.0

# %%
df_2010s.head()
# Out:
#          lat        long    yyyymmdd                 basin_name  station_id  \
# 0  48.566667 -115.450000  2011-02-10  KOOTENAI RIVER IN MONTANA         311
# 1  48.300000 -116.066667  2011-02-10  KOOTENAI RIVER IN MONTANA         323
# 2  48.983333 -115.816667  2011-02-10  KOOTENAI RIVER IN MONTANA         918
# 3  48.916667 -114.766667  2011-02-10  KOOTENAI RIVER IN MONTANA         500
# 4  48.300000 -114.833333  2011-02-10  KOOTENAI RIVER IN MONTANA         510
#
#   acton_id       station_name  elevation  wteq_amt  wteq_med  \
# 0   15A08S  Banfield Mountain       5600      12.1      12.2
# 1   16A08S      Bear Mountain       5400      37.4      38.6
# 2   15A05S       Garver Creek       4250       7.7       6.9
# 3   14A11S        Grave Creek       4300      13.1      11.4
# 4   14A14S         Hand Creek       5035       9.6       7.8
#
#    wteq_amt_pct_med  prec_wytd_amt  prec_wytd_avg  prec_wytd_pctavg
# 0              99.0           17.5           17.8              98.0
# 1              97.0           54.2           49.5             109.0
# 2             112.0           12.2           12.9              95.0
# 3             115.0           18.6           22.8              82.0
# 4             123.0           14.7           11.7             126.0

# %%
df_2000s.shape
# Out:
# (3014, 14)

# %%
df_2010s.shape
# Out:
# (3008, 14)

# %%
df_2000s['yyyymmdd'] = pd.to_datetime(df_2000s['yyyymmdd'])
df_2010s['yyyymmdd'] = pd.to_datetime(df_2010s['yyyymmdd'])

# %%
df_2000s.set_index('yyyymmdd', inplace = True)
df_2010s.set_index('yyyymmdd', inplace = True)

# %%
df_list = [df, df_2000s, df_2010s]

# %%
full_df = pd.concat(df_list, axis = 0)

# %%
full_df
# Out:
#                   lat        long  \
# 1990-02-10  48.566667 -115.450000
# 1990-02-10  45.000000 -117.166667
# 1990-02-10  45.083333 -117.550000
# 1990-02-10  45.066667 -118.150000
# 1990-02-10  44.300000 -115.233333
# ...               ...         ...
# 2021-02-10  47.333333 -121.466667
# 2021-02-10  47.283333 -121.666667
# 2021-02-10  48.516667 -120.733333
# 2021-02-10  47.266667 -121.333333
# 2021-02-10  48.533333 -120.983333
#
#                                                    basin_name station_id  \
# 1990-02-10                          KOOTENAI RIVER IN MONTANA        311
# 1990-02-10                 GRAND RONDE, POWDER, BURNT, IMNAHA        736
# 1990-02-10                 GRAND RONDE, POWDER, BURNT, IMNAHA        812
# 1990-02-10                 GRAND RONDE, POWDER, BURNT, IMNAHA        873
# 1990-02-10                              CLEARWATER AND SALMON        312
# ...                                                       ...        ...
# 2021-02-10  WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAK...        899
# 2021-02-10  WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAK...        420
# 2021-02-10  WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAK...        711
# 2021-02-10  WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAK...        788
# 2021-02-10  WHITE, GREEN, CEDAR, SKYKOMISH, SNOQUALMI, BAK...        817
#
#            acton_id       station_name elevation  wteq_amt  wteq_med  \
# 1990-02-10   15A08S  Banfield Mountain      5600      17.2      12.2
# 1990-02-10   17D08S  Schneider Meadows      5400      21.6      22.0
# 1990-02-10   17D07S       Taylor Green      5740       9.8      15.2
# 1990-02-10   18D21S         Wolf Creek      5630       8.4      12.6
# 1990-02-10   15E11S      Banner Summit      7040      15.1      16.8
# ...             ...                ...       ...       ...       ...
# 2021-02-10   21B20S      Tinkham Creek      2990      21.4      21.4
# 2021-02-10   21B42S    Cougar Mountain      3200       6.4      12.6
# 2021-02-10   20A09S         Rainy Pass      4890      29.6      27.0
# 2021-02-10   21B10S      Stampede Pass      3850      29.3      29.5
# 2021-02-10   20A07S      Thunder Basin      4320      13.0      23.9
#
#             wteq_amt_pct_med  prec_wytd_amt  prec_wytd_avg  prec_wytd_pctavg
# 1990-02-10             141.0           23.8           17.8             134.0
# 1990-02-10              98.0           21.3           26.7              80.0
# 1990-02-10              64.0           15.0           19.2              78.0
# 1990-02-10              67.0           10.2           14.5              70.0
# 1990-02-10              90.0           18.4           21.0              88.0
# ...                      ...            ...            ...               ...
# 2021-02-10             100.0           69.0           61.1             113.0
# 2021-02-10              51.0           59.6           53.8             111.0
# 2021-02-10             110.0           35.7           33.5             107.0
# 2021-02-10              99.0           53.0           53.0             100.0
# 2021-02-10              91.0           45.6           43.5             105.0
#
# [8812 rows x 13 columns]

# %%
full_df.describe()
# Out:
#                lat         long     wteq_amt     wteq_med  wteq_amt_pct_med  \
# count  8812.000000  8812.000000  8812.000000  8812.000000       8812.000000
# mean     45.426398  -116.435764    16.031355    15.847878        101.752440
# std       1.855368     3.536988    10.403040     8.262380         40.035746
# min      41.233333  -123.366667     0.000000     0.000000          0.000000
# 25%      43.950000  -119.833333     8.700000     9.900000         78.000000
# 50%      45.183333  -115.700000    13.700000    14.000000         99.000000
# 75%      46.983333  -113.950000    21.200000    20.700000        121.000000
# max      48.983333  -110.050000    71.900000    47.600000        622.000000
#
#        prec_wytd_amt  prec_wytd_avg  prec_wytd_pctavg
# count    8812.000000    8812.000000       8812.000000
# mean       25.145098      24.859998        101.081480
# std        17.415914      15.231577         28.114302
# min         2.700000       6.000000         30.000000
# 25%        13.200000      14.100000         82.000000
# 50%        20.000000      21.100000         99.000000
# 75%        31.700000      31.700000        117.000000
# max       160.500000      99.400000        234.000000

# %% [markdown]
# ### Distribution / Plots

# %%
years = [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999]

# %%
plt.figure(figsize=(12, 10))
plt.hist(df['wteq_amt'])
plt.title('Distribution of Current Snow Water Levels on Feb 10th in Columbia River Basin 1990-1999')
plt.xlabel('Level of Snow Water (inches)')
plt.ylabel('Number of Occurrences')
plt.style.use('ggplot')

# %%
plt.figure(figsize=(12, 10))
plt.hist(full_df['wteq_amt'])
plt.title('Distribution of Current Snow Water Levels on Feb 10th in Columbia River Basin 1990-2021')
plt.xlabel('Level of Snow Water (inches)')
plt.ylabel('Number of Occurrences')
plt.style.use('ggplot')

# %%
plt.figure(figsize=(12, 10))
plt.hist(df['prec_wytd_amt'])
plt.title('Distribution of YTD Percipitation Levels on Feb 10th in Columbia River Basin 1990-1999')
plt.xlabel('Level of Percipitation to date (inches)')
plt.ylabel('Number of Occurrences')
plt.style.use('ggplot')

# %%
full_df['elevation'] = full_df['elevation'].astype(float)

# %%
plt.figure(figsize=(12, 10))
plt.scatter(x=full_df['lat'], y=full_df['elevation'])
plt.title('SNOTEL Site Elevation in Columbia River Basin 1990-2010')
plt.xlabel('Latitude')
plt.ylabel('Station Elevation (feet)')

plt.style.use('ggplot')

# %%
sns.pairplot(df)
plt.title('1990s Pairplot');

# %%
sns.pairplot(full_df);

# %%
df.corr()
# Out:
#                        lat      long  wteq_amt  wteq_med  wteq_amt_pct_med  \
# lat               1.000000 -0.184859  0.295255  0.346959          0.056378
# long             -0.184859  1.000000 -0.098577 -0.188494          0.070795
# wteq_amt          0.295255 -0.098577  1.000000  0.782230          0.548108
# wteq_med          0.346959 -0.188494  0.782230  1.000000          0.032200
# wteq_amt_pct_med  0.056378  0.070795  0.548108  0.032200          1.000000
# prec_wytd_amt     0.273982 -0.519138  0.608773  0.548833          0.283348
# prec_wytd_avg     0.305668 -0.617812  0.459642  0.634537         -0.003841
# prec_wytd_pctavg  0.076294  0.003149  0.448226  0.045614          0.696751
#
#                   prec_wytd_amt  prec_wytd_avg  prec_wytd_pctavg
# lat                    0.273982       0.305668          0.076294
# long                  -0.519138      -0.617812          0.003149
# wteq_amt               0.608773       0.459642          0.448226
# wteq_med               0.548833       0.634537          0.045614
# wteq_amt_pct_med       0.283348      -0.003841          0.696751
# prec_wytd_amt          1.000000       0.843699          0.472664
# prec_wytd_avg          0.843699       1.000000          0.045258
# prec_wytd_pctavg       0.472664       0.045258          1.000000

# %%
plt.figure(figsize=(12, 10))
sns.boxplot(x=df.index.year, y=df['wteq_amt'])
plt.title('Feb 10th Snow Water Equivalent Levels in Columbia River Basin 1990-1999')
plt.xlabel('Year')
plt.ylabel('Current Snow Water Equivalent (inches)')
plt.style.use('ggplot')

# %%
plt.figure(figsize=(12, 10))
plt.plot(full_df.groupby(full_df.index)['wteq_amt'].mean(), color='b')
plt.title(
    'Average Feb 10th Snow Water Equivalent Levels in Columbia River Basin 1990-2021')
plt.xlabel('Year')
plt.ylabel('Average Current Snow Water Equivalent (inches)')
# Out:
# Text(0, 0.5, 'Average Current Snow Water Equivalent (inches)')

# %%
plt.figure(figsize=(12, 10))
sns.scatterplot(x='wteq_med', y='wteq_amt', data=full_df)
plt.xlabel('Snow Water Equivalent Median (inches)')
plt.ylabel('Recorded Snow Water Equivalent (inches)')
plt.title('Recorded Snow Water Equivalent vs Median Snow Water Equivalent 1990-2021')
# Out:
# Text(0.5, 1.0, 'Recorded Snow Water Equivalent vs Median Snow Water Equivalent 1990-2021')
